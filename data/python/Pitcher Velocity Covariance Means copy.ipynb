# %%
# libraries
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import gc
from matplotlib import style
from pybaseball import statcast
import progressbar 
import warnings
import psycopg2

# pd.options.mode.chained_assignment = None  # default='warn'
# warnings.simplefilter(action='ignore', category=FutureWarning)
# pd.options.display.float_format = '{:.3f}'.format

df_sc = statcast(start_dt='2024-01-01', end_dt='2024-09-30')
# Out:
# This is a large query, it may take a moment to complete
# Skipping offseason dates
#   8%|▊         | 17/200 [00:14<02:04,  1.47it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#   9%|▉         | 18/200 [00:15<02:00,  1.51it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  10%|▉         | 19/200 [00:15<01:47,  1.68it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  10%|█         | 21/200 [00:15<01:21,  2.20it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  12%|█▏        | 23/200 [00:15<01:05,  2.70it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  12%|█▎        | 25/200 [00:21<03:16,  1.12s/it]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  13%|█▎        | 26/200 [00:21<02:48,  1.04it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  14%|█▍        | 29/200 [00:22<01:55,  1.48it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  15%|█▌        | 30/200 [00:22<01:40,  1.69it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  16%|█▌        | 32/200 [00:23<01:17,  2.18it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  17%|█▋        | 34/200 [00:23<00:57,  2.90it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  18%|█▊        | 37/200 [00:31<03:31,  1.30s/it]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  19%|█▉        | 38/200 [00:31<03:04,  1.14s/it]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  20%|██        | 40/200 [00:32<02:09,  1.24it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  23%|██▎       | 46/200 [00:34<01:14,  2.07it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  24%|██▍       | 49/200 [00:37<01:34,  1.59it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  25%|██▌       | 50/200 [00:37<01:19,  1.89it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  26%|██▌       | 51/200 [00:37<01:12,  2.04it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  26%|██▋       | 53/200 [00:38<01:08,  2.16it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  27%|██▋       | 54/200 [00:41<02:31,  1.04s/it]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  28%|██▊       | 55/200 [00:42<02:12,  1.10it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  28%|██▊       | 56/200 [00:42<01:42,  1.41it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  28%|██▊       | 57/200 [00:42<01:39,  1.44it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  29%|██▉       | 58/200 [00:42<01:16,  1.84it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  30%|██▉       | 59/200 [00:43<01:04,  2.20it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  30%|███       | 61/200 [00:44<01:24,  1.64it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  31%|███       | 62/200 [00:45<01:14,  1.86it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  32%|███▏      | 64/200 [00:45<00:50,  2.71it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  32%|███▎      | 65/200 [00:46<01:01,  2.21it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  33%|███▎      | 66/200 [00:49<02:37,  1.17s/it]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  34%|███▎      | 67/200 [00:50<02:29,  1.12s/it]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  34%|███▍      | 69/200 [00:51<01:39,  1.32it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  35%|███▌      | 70/200 [00:51<01:19,  1.63it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  36%|███▌      | 71/200 [00:51<01:06,  1.94it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  36%|███▋      | 73/200 [00:53<01:31,  1.38it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  37%|███▋      | 74/200 [00:53<01:13,  1.71it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  38%|███▊      | 75/200 [00:53<01:03,  1.98it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  38%|███▊      | 77/200 [00:54<00:52,  2.35it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  39%|███▉      | 78/200 [00:58<02:23,  1.18s/it]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  40%|███▉      | 79/200 [00:59<02:15,  1.12s/it]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  40%|████      | 80/200 [00:59<01:43,  1.16it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  40%|████      | 81/200 [01:00<01:40,  1.18it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  42%|████▏     | 83/200 [01:00<01:02,  1.87it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#  42%|████▎     | 85/200 [01:01<01:12,  1.59it/s]/opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#
#
#         player_name  batter  pitcher     events      description  ...  \
# 202     Díaz, Edwin  518595   621242  field_out    hit_into_play  ...
# 205     Díaz, Edwin  518595   621242        NaN             ball  ...
# 209     Díaz, Edwin  518595   621242        NaN  swinging_strike  ...
# 214     Díaz, Edwin  518595   621242        NaN             ball  ...
# 221     Díaz, Edwin  518595   621242        NaN  swinging_strike  ...
# ...             ...     ...      ...        ...              ...  ...
# 1721  Singer, Brady  666310   663903       None  swinging_strike  ...
# 1776  Singer, Brady  666310   663903       None  swinging_strike  ...
# 1859  Singer, Brady  608070   663903     double    hit_into_play  ...
# 1953  Singer, Brady  665926   663903  field_out    hit_into_play  ...
# 2116  Singer, Brady  680757   663903  field_out    hit_into_play  ...
#
#       n_thruorder_pitcher  n_priorpa_thisgame_player_at_bat  \
# 202                     1                                 4
# 205                     1                                 4
# 209                     1                                 4
# 214                     1                                 4
# 221                     1                                 4
# ...                   ...                               ...
# 1721                    1                                 0
# 1776                    1                                 0
# 1859                    1                                 0
# 1953                    1                                 0
# 2116                    1                                 0
#
#       pitcher_days_since_prev_game  batter_days_since_prev_game  \
# 202                              1                            1
# 205                              1                            1
# 209                              1                            1
# 214                              1                            1
# 221                              1                            1
# ...                            ...                          ...
# 1721                          <NA>                         <NA>
# 1776                          <NA>                         <NA>
# 1859                          <NA>                         <NA>
# 1953                          <NA>                         <NA>
# 2116                          <NA>                         <NA>
#
#       pitcher_days_until_next_game batter_days_until_next_game  \
# 202                              3                           1
# 205                              3                           1
# 209                              3                           1
# 214                              3                           1
# 221                              3                           1
# ...                            ...                         ...
# 1721                          <NA>                        <NA>
# 1776                          <NA>                        <NA>
# 1859                          <NA>                        <NA>
# 1953                          <NA>                        <NA>
# 2116                          <NA>                        <NA>
#
#      api_break_z_with_gravity api_break_x_arm api_break_x_batter_in arm_angle
# 202                       1.4            0.96                  0.96      17.6
# 205                      2.14            -0.2                  -0.2      23.1
# 209                      2.37           -0.12                 -0.12      22.4
# 214                      2.09           -0.21                 -0.21      22.4
# 221                       2.2           -0.17                 -0.17      20.2
# ...                       ...             ...                   ...       ...
# 1721                     <NA>            <NA>                  <NA>      <NA>
# 1776                     <NA>            <NA>                  <NA>      <NA>
# 1859                     <NA>            <NA>                  <NA>      <NA>
# 1953                     <NA>            <NA>                  <NA>      <NA>
# 2116                     <NA>            <NA>                  <NA>      <NA>
#
# [744927 rows x 113 columns]

# %%
import pandas as pd

# Mapping
result_map = {
    'pitchout_hit_into_play_score': 'contact',
    'hit_into_play_score': 'contact',
    'hit_into_play': 'contact',
    'hit_by_pitch': 'contact',
    'hit_into_play_no_out': 'contact',
    'pitchout_hit_into_play_no_out': 'contact',
    'pitchout_hit_into_play': 'contact',
    'foul_pitchout': 'foul',
    'foul_bunt': 'foul',
    'bunt_foul_tip': 'foul',
    'foul': 'foul',
    'foul_tip': 'foul',
    'intent_ball': 'take',
    'blocked_ball': 'take',
    'pitchout': 'take',
    'ball': 'take',
    'called_strike': 'take',
    'unknown_strike': 'whiff',
    'swinging_strike_blocked': 'whiff',
    'swinging_pitchout': 'whiff',
    'missed_bunt': 'whiff',
    'swinging_strike': 'whiff'
}

# Apply mapping
df_sc['result_type'] = df_sc['description'].map(result_map)

# Define what counts as a "swing"
# df_sc.groupby(['batter', 'pitch_type'])['result_type'].value_counts(normalize=True).unstack().fillna(0).reset_index()

df_swing_pct = df_sc.groupby(['batter', 'pitch_type', 'zone']).agg(
    contact_pct=('result_type', lambda x: (x == 'contact').mean()),
    foul_pct=('result_type', lambda x: (x == 'foul').mean()),
    whiff_pct=('result_type', lambda x: (x == 'whiff').mean()),
    take_pct=('result_type', lambda x: (x == 'take').mean()),
    count=('result_type', 'count')
).reset_index()


df_swing_pct
# Out:
#        batter pitch_type  zone  contact_pct  foul_pct  whiff_pct  take_pct  \
# 0      444482         CH     1     0.500000  0.166667   0.000000  0.333333
# 1      444482         CH     4     1.000000  0.000000   0.000000  0.000000
# 2      444482         CH     5     0.333333  0.333333   0.333333  0.000000
# 3      444482         CH     6     0.750000  0.250000   0.000000  0.000000
# 4      444482         CH     7     0.363636  0.272727   0.363636  0.000000
# ...       ...        ...   ...          ...       ...        ...       ...
# 65838  815888         FC     9     0.000000  1.000000   0.000000  0.000000
# 65839  815888         FC    12     0.000000  0.000000   0.000000  1.000000
# 65840  815888         FF     4     0.000000  0.000000   1.000000  0.000000
# 65841  815888         FF    11     0.500000  0.500000   0.000000  0.000000
# 65842  815888         ST    13     0.000000  0.000000   0.000000  1.000000
#
#        count
# 0          6
# 1          8
# 2          3
# 3          4
# 4         11
# ...      ...
# 65838      1
# 65839      1
# 65840      1
# 65841      2
# 65842      3
#
# [65843 rows x 8 columns]

# %%
import psycopg2
import pandas as pd

# Connect to PostgreSQL
conn = psycopg2.connect(
    dbname="postgres",
    user="postgres",
    password="Gabriela3$",
    host="piedmont-db.cp6uayweg6ql.us-east-2.rds.amazonaws.com",
    port="5432"
)
cur = conn.cursor()

# Ensure the table exists
cur.execute("""
    CREATE TABLE IF NOT EXISTS pitcher_pitch_covariance_mean (
        pitcher BIGINT,
        player_name TEXT,
        pitch_type TEXT,
        mean_plate_x FLOAT,
        mean_plate_z FLOAT,
        cov_plate_xx FLOAT,
        cov_plate_zz FLOAT,
        cov_plate_xz FLOAT
    )
""")

# Insert data
for _, row in pitcher_covariance_mean.iterrows():
    cur.execute("""
        INSERT INTO pitcher_pitch_covariance_mean (pitcher, player_name, pitch_type, mean_plate_x, mean_plate_z, cov_plate_xx, cov_plate_zz, cov_plate_xz)
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
    """, (row['pitcher'], row['player_name'], row['pitch_type'], row['mean_plate_x'], row['mean_plate_z'], row['cov_plate_xx'], row['cov_plate_zz'], row['cov_plate_xz']))

# Commit and close connection
conn.commit()
cur.close()
conn.close()

print("Data successfully inserted into PostgreSQL!")
